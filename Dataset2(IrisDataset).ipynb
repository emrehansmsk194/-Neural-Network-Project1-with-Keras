# %%
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
Y = iris.target  # Target labels

# Display the shapes of the features and target
print(X.shape)  # Should print (150, 4)
print(Y.shape)  # Should print (150,)
# Out:
# (150, 4)
# (150,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.25, random_state=42)

# %%
from keras.utils import to_categorical

# One-hot encode the target labels
Y_train_one_hot = to_categorical(Y_train)
Y_val_one_hot = to_categorical(Y_val)

# %%
from keras import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam, SGD  

model = Sequential()

learning_rate = 0.01

optimizer = SGD(learning_rate=learning_rate)

# %%
model.add(Dense(64, activation='relu', input_shape=(4,)))  
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer= optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# C:\Users\Dell\.conda\lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,835 (34.51 KB)
#  Trainable params: 8,835 (34.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model with one-hot encoded target labels
h = model.fit(X_train, Y_train_one_hot, epochs=50, validation_data=(X_val, Y_val_one_hot), batch_size=32)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.3519 - loss: 1.0903 - val_accuracy: 0.2667 - val_loss: 1.0653
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3363 - loss: 0.9857 - val_accuracy: 0.2667 - val_loss: 0.9708
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3591 - loss: 0.9176 - val_accuracy: 0.4333 - val_loss: 0.9313
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6592 - loss: 0.8853 - val_accuracy: 0.5667 - val_loss: 0.9149
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6882 - loss: 0.8481 - val_accuracy: 0.5667 - val_loss: 0.8868
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6843 - loss: 0.8299 - val_accuracy: 0.5667 - val_loss: 0.8674
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7194 - loss: 0.8127 - val_accuracy: 0.5667 - val_loss: 0.8389
# Epoch 8/50
# ...

# %%
h = model.fit(X_train, Y_train_one_hot, epochs=100, validation_data=(X_val, Y_val_one_hot), batch_size=64)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9778 - loss: 0.3916 - val_accuracy: 0.9333 - val_loss: 0.4478
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9800 - loss: 0.3773 - val_accuracy: 0.8667 - val_loss: 0.4566
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9369 - loss: 0.3777 - val_accuracy: 0.7333 - val_loss: 0.4744
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8821 - loss: 0.3730 - val_accuracy: 0.8667 - val_loss: 0.4558
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9243 - loss: 0.3742 - val_accuracy: 0.7000 - val_loss: 0.4861
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8042 - loss: 0.3659 - val_accuracy: 0.8667 - val_loss: 0.4541
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9199 - loss: 0.3644 - val_accuracy: 0.9333 - val_loss: 0.4292
# Epoch 8/100
# ...

# %%
model = Sequential()

learning_rate = 0.01

optimizer = Adam(learning_rate=learning_rate)

# %%
model.add(Dense(64, activation='relu', input_shape=(4,)))  # İlk gizli katman, 64 nöron ve ReLU aktivasyonu
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer= optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
h = model.fit(X_train, Y_train_one_hot, epochs=50, validation_data=(X_val, Y_val_one_hot), batch_size=64)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.2493 - loss: 1.6031 - val_accuracy: 0.7333 - val_loss: 0.9838
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5883 - loss: 1.1409 - val_accuracy: 0.5667 - val_loss: 1.2214
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6676 - loss: 1.0194 - val_accuracy: 0.5667 - val_loss: 0.8598
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6936 - loss: 0.7005 - val_accuracy: 0.8667 - val_loss: 0.6222
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8376 - loss: 0.5848 - val_accuracy: 0.9000 - val_loss: 0.5080
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9259 - loss: 0.4595 - val_accuracy: 0.7000 - val_loss: 0.4941
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8442 - loss: 0.3522 - val_accuracy: 0.9333 - val_loss: 0.3824
# Epoch 8/50
# ...

# %%
model = Sequential()

learning_rate = 0.001

optimizer = Adam(learning_rate=learning_rate)

# %%
model.add(Dense(64, activation='relu', input_shape=(4,)))  # İlk gizli katman, 64 nöron ve ReLU aktivasyonu
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer= optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
h = model.fit(X_train, Y_train_one_hot, epochs=50, validation_data=(X_val, Y_val_one_hot), batch_size=16)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4639 - loss: 1.1756 - val_accuracy: 0.7333 - val_loss: 0.9674
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7367 - loss: 0.9125 - val_accuracy: 0.5667 - val_loss: 0.8916
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6540 - loss: 0.8175 - val_accuracy: 0.5667 - val_loss: 0.7934
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7111 - loss: 0.6820 - val_accuracy: 0.8000 - val_loss: 0.6772
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9402 - loss: 0.5816 - val_accuracy: 0.8333 - val_loss: 0.6004
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8817 - loss: 0.4909 - val_accuracy: 0.7667 - val_loss: 0.5508
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8872 - loss: 0.4574 - val_accuracy: 0.9000 - val_loss: 0.4895
# Epoch 8/50
# ...

# %%
from keras.optimizers import Adam, RMSprop

# %%
model = Sequential()

learning_rate = 0.01

optimizer = RMSprop(learning_rate=learning_rate)

# %%
model.add(Dense(64, activation='relu', input_shape=(4,)))  
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer= optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
h = model.fit(X_train, Y_train_one_hot, epochs=100, validation_data=(X_val, Y_val_one_hot), batch_size=32)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.2655 - loss: 1.9890 - val_accuracy: 0.3667 - val_loss: 0.8586
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6602 - loss: 0.6954 - val_accuracy: 0.5667 - val_loss: 0.6158
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7312 - loss: 0.4655 - val_accuracy: 0.7333 - val_loss: 0.5133
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5835 - loss: 0.5465 - val_accuracy: 0.5667 - val_loss: 0.5207
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7672 - loss: 0.4100 - val_accuracy: 0.6667 - val_loss: 0.4739
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6670 - loss: 0.4656 - val_accuracy: 0.8667 - val_loss: 0.4319
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8408 - loss: 0.3715 - val_accuracy: 0.6000 - val_loss: 0.5414
# Epoch 8/100
# ...

# %%
model = Sequential()

learning_rate = 0.001

optimizer = RMSprop(learning_rate=learning_rate)

# %%
model.add(Dense(64, activation='relu', input_shape=(4,)))  
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer= optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
h = model.fit(X_train, Y_train_one_hot, epochs=100, validation_data=(X_val, Y_val_one_hot), batch_size=16)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4470 - loss: 1.2353 - val_accuracy: 0.7333 - val_loss: 0.9192
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6727 - loss: 0.9124 - val_accuracy: 0.9000 - val_loss: 0.8486
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8189 - loss: 0.7803 - val_accuracy: 0.7667 - val_loss: 0.7571
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7946 - loss: 0.7204 - val_accuracy: 0.5667 - val_loss: 0.7373
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7429 - loss: 0.6153 - val_accuracy: 0.9000 - val_loss: 0.6422
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9339 - loss: 0.5673 - val_accuracy: 0.7667 - val_loss: 0.6152
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9234 - loss: 0.5320 - val_accuracy: 0.6333 - val_loss: 0.5930
# Epoch 8/100
# ...

# %%
model = Sequential()

learning_rate = 0.1

optimizer = RMSprop(learning_rate=learning_rate)

# %%
model.add(Dense(64, activation='relu', input_shape=(4,)))  
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer= optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
h = model.fit(X_train, Y_train_one_hot, epochs=200, validation_data=(X_val, Y_val_one_hot), batch_size=64)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.0919 - loss: 23.5993 - val_accuracy: 0.3000 - val_loss: 21.8704
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3442 - loss: 25.7500 - val_accuracy: 0.4333 - val_loss: 8.2129
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3168 - loss: 8.5620 - val_accuracy: 0.3333 - val_loss: 3.3028
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3999 - loss: 2.0854 - val_accuracy: 0.6667 - val_loss: 0.9632
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5334 - loss: 0.9914 - val_accuracy: 0.7333 - val_loss: 0.6781
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6209 - loss: 0.6369 - val_accuracy: 0.7333 - val_loss: 0.5860
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6558 - loss: 0.5664 - val_accuracy: 0.5667 - val_loss: 0.5645
# Epoch 8/200
# ...

# %%
from sklearn.utils import shuffle
X_shuffled, Y_shuffled = shuffle(X, Y, random_state=42)

# %%
from sklearn.preprocessing import normalize
X_normalized = normalize(X_shuffled, axis=0)

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, Y_train, Y_test = train_test_split(X_shuffled, Y_shuffled, test_size=0.2, random_state=42)


(X_train.shape, Y_train.shape), (X_test.shape, Y_test.shape)
# Out:
# (((120, 4), (120,)), ((30, 4), (30,)))

# %%
from keras.utils import to_categorical
y_train=to_categorical(Y_train,num_classes=3) #Convert label to one-hot
y_test=to_categorical(Y_test,num_classes=3)

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import Adam,SGD
learning_rate = 0.001
optimizer = Adam(learning_rate = learning_rate)

# %%
model = Sequential()

model.add(Dense(1024,input_dim=4,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# C:\Users\Dell\.conda\lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=32,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4290 - loss: 1.0081 - val_accuracy: 0.6333 - val_loss: 0.6753
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7071 - loss: 0.6866 - val_accuracy: 0.6333 - val_loss: 0.4847
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7117 - loss: 0.4855 - val_accuracy: 0.9667 - val_loss: 0.3494
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8194 - loss: 0.3672 - val_accuracy: 1.0000 - val_loss: 0.2468
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9315 - loss: 0.3134 - val_accuracy: 1.0000 - val_loss: 0.1806
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9206 - loss: 0.2532 - val_accuracy: 1.0000 - val_loss: 0.1221
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9325 - loss: 0.2124 - val_accuracy: 1.0000 - val_loss: 0.0850
# Epoch 8/50
# ...

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=64,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9729 - loss: 0.0871 - val_accuracy: 0.9667 - val_loss: 0.0499
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9726 - loss: 0.0845 - val_accuracy: 0.9667 - val_loss: 0.0570
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9622 - loss: 0.0854 - val_accuracy: 1.0000 - val_loss: 0.0251
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9781 - loss: 0.0686 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9729 - loss: 0.0821 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9729 - loss: 0.0837 - val_accuracy: 0.9667 - val_loss: 0.0296
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9837 - loss: 0.0631 - val_accuracy: 0.9667 - val_loss: 0.0524
# Epoch 8/50
# ...

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=64,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9837 - loss: 0.0567 - val_accuracy: 0.9667 - val_loss: 0.0334
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9785 - loss: 0.0624 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9781 - loss: 0.0514 - val_accuracy: 1.0000 - val_loss: 0.0183
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9785 - loss: 0.0677 - val_accuracy: 1.0000 - val_loss: 0.0254
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9892 - loss: 0.0630 - val_accuracy: 1.0000 - val_loss: 0.0250
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9837 - loss: 0.0558 - val_accuracy: 0.9667 - val_loss: 0.0274
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9889 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 8/100
# ...
